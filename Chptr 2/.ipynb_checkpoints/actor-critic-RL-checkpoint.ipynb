# %%
import numpy as np
import tensorflow as tf
import gym
import tensorflow_probability as tfp
import matplotlib.pyplot as plt

# %%
class ActorCritic(tf.keras.Model):
    def __init__(self, action_dim):
        super().__init__()
        self.fc1 = tf.keras.layers.Dense(512, activation="relu")
        self.fc2 = tf.keras.layers.Dense(128, activation="relu")
        self.critic = tf.keras.layers.Dense(1, activation=None)
        self.actor = tf.keras.layers.Dense(action_dim, activation=None)
        
    def call(self, input_data):
        x = self.fc1(input_data)
        x1 = self.fc2(x)
        actor = self.actor(x1)
        critic = self.critic(x1)
        return critic, actor

# %%
class Agent:
    def __init__(self, action_dim=4, gamma=0.99):
        """Agent with a neural-network brain powered policy
        Args:
            action_dim (int): Action dimension
            gamma (float) : Discount factor. Default=0.99
        """
        self.gamma = gamma
        self.opt = tf.keras.optimizers.Adam(learning_rate=1e-4)
        self.actor_critic = ActorCritic(action_dim)
    
    def get_action(self, state):
        _, action_probabilities = self.actor_critic(np.array([state]))
        action_probabilities = tf.nn.softmax(
        action_probabilities)
        action_probabilities = action_probabilities.numpy()
        dist = tfp.distributions.Categorical(probs=action_probabilities, dtype=tf.float32)
        action = dist.sample()
        return int(action.numpy()[0])
    
    def actor_loss(self, prob, action, td):
        prob = tf.nn.softmax(prob)
        dist = tfp.distributions.Categorical(probs=prob,
        dtype=tf.float32)
        log_prob = dist.log_prob(action)
        loss = -log_prob * td
        return loss
    
    def learn(self, state, action, reward, next_state, done):
        state = np.array([state])
        next_state = np.array([next_state])
        with tf.GradientTape() as tape:
            value, action_probabilities = self.actor_critic(state, training=True)
            value_next_st, _ = self.actor_critic(next_state, training=True)
            td = reward + self.gamma * value_next_st * (1 - int(done)) - value
            actor_loss = self.actor_loss(action_probabilities, action, td)
            critic_loss = td ** 2
            total_loss = actor_loss + critic_loss
        grads = tape.gradient(total_loss,self.actor_critic.trainable_variables)
        self.opt.apply_gradients(zip(grads,self.actor_critic.trainable_variables))
        return total_loss

# %%
def train(agent, env, episodes, render=True):
    """Train `agent` in `env` for `episodes`
    Args:
        agent (Agent): Agent to train
        env (gym.Env): Environment to train the agent
        episodes (int): Number of episodes to train
        render (bool): True=Enable/False=Disable rendering; Default=True
    """
    rewards = []
    for episode in range(episodes):
        done = False
        state = env.reset()
        total_reward = 0
        all_loss = []
        while not done:
            action = agent.get_action(state)
            next_state, reward, done, _ = env.step(action)
            loss = agent.learn(state, action, reward, next_state, done)
            all_loss.append(loss)
            state = next_state
            total_reward += reward
            if render:
                env.render()
            if done:
                print("\n")
        rewards.append(total_reward)
        print(f"Episode#:{episode} ep_reward:{total_reward}", end="\r")
    return rewards

# %%
def createGraph(rewards):
    x_val = list(range(0,len(rewards)))
    y_val = rewards.copy()
    plt.plot(x_val, y_val)
    plt.xlabel('Episode')
    plt.ylabel('Rewards')

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    agent = Agent(env.action_space.n)
    num_episodes = 1000
    rewards = train(agent, env, num_episodes)
    createGraph(rewards)
# Out:
# Episode#:0 ep_reward:48.0
#
# Episode#:1 ep_reward:29.0
#
# Episode#:2 ep_reward:13.0
#
# Episode#:3 ep_reward:20.0
#
# Episode#:4 ep_reward:14.0
#
# Episode#:5 ep_reward:19.0
#
# Episode#:6 ep_reward:19.0
#
# Episode#:7 ep_reward:15.0
#
# Episode#:8 ep_reward:15.0
#
# Episode#:9 ep_reward:24.0
#
# Episode#:10 ep_reward:27.0
#
# Episode#:11 ep_reward:14.0
#
# Episode#:12 ep_reward:23.0
#
# Episode#:13 ep_reward:31.0
#
# Episode#:14 ep_reward:17.0
#
# Episode#:15 ep_reward:11.0
#
# Episode#:16 ep_reward:23.0
#
# Episode#:17 ep_reward:16.0
#
# Episode#:18 ep_reward:12.0
#
# Episode#:19 ep_reward:15.0
#
# Episode#:20 ep_reward:59.0
#
# Episode#:21 ep_reward:49.0
#
# Episode#:22 ep_reward:12.0
#
# Episode#:23 ep_reward:23.0
#
# Episode#:24 ep_reward:17.0
#
# Episode#:25 ep_reward:22.0
#
# Episode#:26 ep_reward:13.0
#
# Episode#:27 ep_reward:15.0
#
# Episode#:28 ep_reward:12.0
#
# Episode#:29 ep_reward:26.0
#
# Episode#:30 ep_reward:13.0
#
# Episode#:31 ep_reward:14.0
#
# Episode#:32 ep_reward:18.0
#
# Episode#:33 ep_reward:25.0
#
# Episode#:34 ep_reward:12.0
#
# Episode#:35 ep_reward:11.0
#
# Episode#:36 ep_reward:16.0
#
# Episode#:37 ep_reward:13.0
#
# Episode#:38 ep_reward:22.0
#
# Episode#:39 ep_reward:13.0
#
# Episode#:40 ep_reward:10.0
#
# Episode#:41 ep_reward:10.0
#
# Episode#:42 ep_reward:10.0
#
# Episode#:43 ep_reward:17.0
#
# Episode#:44 ep_reward:16.0
#
# Episode#:45 ep_reward:33.0
#
# Episode#:46 ep_reward:11.0
#
# Episode#:47 ep_reward:10.0
#
# Episode#:48 ep_reward:37.0
#
# Episode#:49 ep_reward:13.0
#
# Episode#:50 ep_reward:16.0
#
# Episode#:51 ep_reward:11.0
#
# Episode#:52 ep_reward:11.0
#
# Episode#:53 ep_reward:13.0
#
# Episode#:54 ep_reward:18.0
#
# Episode#:55 ep_reward:10.0
#
# Episode#:56 ep_reward:10.0
#
# Episode#:57 ep_reward:16.0
#
# Episode#:58 ep_reward:12.0
#
# Episode#:59 ep_reward:21.0
#
# Episode#:60 ep_reward:11.0
#
# Episode#:61 ep_reward:22.0
#
# Episode#:62 ep_reward:23.0
#
# Episode#:63 ep_reward:15.0
#
# Episode#:64 ep_reward:13.0
#
# Episode#:65 ep_reward:24.0
#
# Episode#:66 ep_reward:18.0
#
# Episode#:67 ep_reward:12.0
#
# Episode#:68 ep_reward:27.0
#
# Episode#:69 ep_reward:10.0
#
# Episode#:70 ep_reward:16.0
#
# Episode#:71 ep_reward:11.0
#
# Episode#:72 ep_reward:24.0
#
# Episode#:73 ep_reward:10.0
#
# Episode#:74 ep_reward:11.0
#
# Episode#:75 ep_reward:26.0
#
# Episode#:76 ep_reward:11.0
#
# Episode#:77 ep_reward:23.0
#
# Episode#:78 ep_reward:13.0
#
# Episode#:79 ep_reward:13.0
#
# Episode#:80 ep_reward:11.0
#
# Episode#:81 ep_reward:24.0
#
# Episode#:82 ep_reward:11.0
#
# Episode#:83 ep_reward:14.0
#
# Episode#:84 ep_reward:14.0
#
# Episode#:85 ep_reward:13.0
#
# Episode#:86 ep_reward:13.0
#
# Episode#:87 ep_reward:8.0
#
# Episode#:88 ep_reward:10.0
#
# Episode#:89 ep_reward:13.0
#
# Episode#:90 ep_reward:13.0
#
# Episode#:91 ep_reward:11.0
#
# Episode#:92 ep_reward:12.0
#
# Episode#:93 ep_reward:12.0
#
# Episode#:94 ep_reward:17.0
#
# Episode#:95 ep_reward:14.0
#
# Episode#:96 ep_reward:14.0
#
# Episode#:97 ep_reward:18.0
#
# Episode#:98 ep_reward:14.0
#
# Episode#:99 ep_reward:20.0
#
# Episode#:100 ep_reward:15.0
#
# Episode#:101 ep_reward:20.0
#
# Episode#:102 ep_reward:9.0
#
# Episode#:103 ep_reward:12.0
#
# Episode#:104 ep_reward:17.0
#
# Episode#:105 ep_reward:30.0
#
# Episode#:106 ep_reward:22.0
#
# Episode#:107 ep_reward:18.0
#
# Episode#:108 ep_reward:13.0
#
# Episode#:109 ep_reward:22.0
#
# Episode#:110 ep_reward:15.0
#
# Episode#:111 ep_reward:55.0
#
# Episode#:112 ep_reward:13.0
#
# Episode#:113 ep_reward:21.0
#
# Episode#:114 ep_reward:10.0
#
# Episode#:115 ep_reward:11.0
#
# Episode#:116 ep_reward:13.0
#
# Episode#:117 ep_reward:24.0
#
# Episode#:118 ep_reward:28.0
#
# Episode#:119 ep_reward:16.0
#
# Episode#:120 ep_reward:9.0
#
# Episode#:121 ep_reward:11.0
#
# Episode#:122 ep_reward:57.0
#
# Episode#:123 ep_reward:16.0
#
# Episode#:124 ep_reward:16.0
#
# Episode#:125 ep_reward:26.0
#
# Episode#:126 ep_reward:14.0
#
# Episode#:127 ep_reward:23.0
#
# Episode#:128 ep_reward:12.0
#
# Episode#:129 ep_reward:18.0
#
# Episode#:130 ep_reward:10.0
#
# Episode#:131 ep_reward:10.0
#
# Episode#:132 ep_reward:14.0
#
# Episode#:133 ep_reward:14.0
#
# Episode#:134 ep_reward:12.0
#
# Episode#:135 ep_reward:22.0
#
# Episode#:136 ep_reward:19.0
#
# Episode#:137 ep_reward:15.0
#
# Episode#:138 ep_reward:32.0
#
# Episode#:139 ep_reward:14.0
#
# Episode#:140 ep_reward:9.0
#
# Episode#:141 ep_reward:9.0
#
# Episode#:142 ep_reward:12.0
#
# Episode#:143 ep_reward:11.0
#
# Episode#:144 ep_reward:14.0
#
# Episode#:145 ep_reward:10.0
#
# Episode#:146 ep_reward:12.0
#
# Episode#:147 ep_reward:23.0
#
# Episode#:148 ep_reward:22.0
#
# Episode#:149 ep_reward:15.0
#
# Episode#:150 ep_reward:27.0
#
# Episode#:151 ep_reward:13.0
#
# Episode#:152 ep_reward:20.0
#
# Episode#:153 ep_reward:10.0
#
# Episode#:154 ep_reward:49.0
#
# Episode#:155 ep_reward:16.0
#
# Episode#:156 ep_reward:15.0
#
# Episode#:157 ep_reward:13.0
#
# Episode#:158 ep_reward:14.0
#
# Episode#:159 ep_reward:17.0
#
# Episode#:160 ep_reward:16.0
#
# Episode#:161 ep_reward:13.0
#
# Episode#:162 ep_reward:57.0
#
# Episode#:163 ep_reward:15.0
#
# Episode#:164 ep_reward:21.0
#
# Episode#:165 ep_reward:22.0
#
# Episode#:166 ep_reward:31.0
#
# Episode#:167 ep_reward:15.0
#
# Episode#:168 ep_reward:11.0
#
# Episode#:169 ep_reward:12.0
#
# Episode#:170 ep_reward:11.0
#
# Episode#:171 ep_reward:16.0
#
# Episode#:172 ep_reward:13.0
#
# Episode#:173 ep_reward:21.0
#
# Episode#:174 ep_reward:22.0
#
# Episode#:175 ep_reward:15.0
#
# Episode#:176 ep_reward:20.0
#
# Episode#:177 ep_reward:39.0
#
# Episode#:178 ep_reward:36.0
#
# Episode#:179 ep_reward:26.0
#
# Episode#:180 ep_reward:80.0
#
# Episode#:181 ep_reward:59.0
#
# Episode#:182 ep_reward:63.0
#
# Episode#:183 ep_reward:17.0
#
# Episode#:184 ep_reward:19.0
#
# Episode#:185 ep_reward:39.0
#
# Episode#:186 ep_reward:20.0
#
# Episode#:187 ep_reward:18.0
#
# Episode#:188 ep_reward:76.0
#
# Episode#:189 ep_reward:59.0
#
# Episode#:190 ep_reward:20.0
#
# Episode#:191 ep_reward:27.0
#
# Episode#:192 ep_reward:46.0
#
# Episode#:193 ep_reward:67.0
#
# Episode#:194 ep_reward:77.0
#
# Episode#:195 ep_reward:84.0
#
# Episode#:196 ep_reward:55.0
#
# Episode#:197 ep_reward:55.0
#
# Episode#:198 ep_reward:72.0
#
# Episode#:199 ep_reward:35.0
#
# Episode#:200 ep_reward:88.0
#
# Episode#:201 ep_reward:42.0
#
# Episode#:202 ep_reward:32.0
#
# Episode#:203 ep_reward:28.0
#
# Episode#:204 ep_reward:49.0
#
# Episode#:205 ep_reward:58.0
#
# Episode#:206 ep_reward:41.0
#
# Episode#:207 ep_reward:85.0
#
# Episode#:208 ep_reward:23.0
#
# Episode#:209 ep_reward:66.0
#
# Episode#:210 ep_reward:46.0
#
# Episode#:211 ep_reward:31.0
#
# Episode#:212 ep_reward:23.0
#
# Episode#:213 ep_reward:39.0
#
# Episode#:214 ep_reward:66.0
#
# Episode#:215 ep_reward:84.0
#
# Episode#:216 ep_reward:72.0
#
# Episode#:217 ep_reward:187.0
#
# Episode#:218 ep_reward:52.0
#
# Episode#:219 ep_reward:116.0
#
# Episode#:220 ep_reward:111.0
#
# Episode#:221 ep_reward:126.0
#
# Episode#:222 ep_reward:50.0
#
# Episode#:223 ep_reward:76.0
#
# Episode#:224 ep_reward:36.0
#
# Episode#:225 ep_reward:117.0
#
# Episode#:226 ep_reward:72.0
#
# Episode#:227 ep_reward:85.0
#
# Episode#:228 ep_reward:53.0
#
# Episode#:229 ep_reward:81.0
#
# Episode#:230 ep_reward:88.0
#
# Episode#:231 ep_reward:90.0
#
# Episode#:232 ep_reward:144.0
#
# Episode#:233 ep_reward:94.0
#
# Episode#:234 ep_reward:102.0
#
# Episode#:235 ep_reward:106.0
#
# Episode#:236 ep_reward:188.0
#
# Episode#:237 ep_reward:184.0
#
# Episode#:238 ep_reward:140.0
#
# Episode#:239 ep_reward:148.0
#
# Episode#:240 ep_reward:200.0
#
# Episode#:241 ep_reward:136.0
#
# Episode#:242 ep_reward:152.0
#
# Episode#:243 ep_reward:95.0
#
# Episode#:244 ep_reward:118.0
#
# Episode#:245 ep_reward:175.0
#
# Episode#:246 ep_reward:113.0
#
# Episode#:247 ep_reward:133.0
#
# Episode#:248 ep_reward:124.0
#
# Episode#:249 ep_reward:67.0
#
# Episode#:250 ep_reward:191.0
#
# Episode#:251 ep_reward:114.0
#
# Episode#:252 ep_reward:141.0
#
# Episode#:253 ep_reward:200.0
#
# Episode#:254 ep_reward:123.0
#
# Episode#:255 ep_reward:121.0
#
# Episode#:256 ep_reward:102.0
#
# Episode#:257 ep_reward:199.0
#
# Episode#:258 ep_reward:118.0
#
# Episode#:259 ep_reward:88.0
#
# Episode#:260 ep_reward:119.0
#
# Episode#:261 ep_reward:122.0
#
# Episode#:262 ep_reward:102.0
#
# Episode#:263 ep_reward:74.0
#
# Episode#:264 ep_reward:60.0
#
# Episode#:265 ep_reward:63.0
#
# Episode#:266 ep_reward:78.0
#
# Episode#:267 ep_reward:105.0
#
# Episode#:268 ep_reward:173.0
#
# Episode#:269 ep_reward:171.0
#
# Episode#:270 ep_reward:173.0
#
# Episode#:271 ep_reward:162.0
#
# Episode#:272 ep_reward:143.0
#
# Episode#:273 ep_reward:119.0
#
# Episode#:274 ep_reward:142.0
#
# Episode#:275 ep_reward:170.0
#
# Episode#:276 ep_reward:150.0
#
# Episode#:277 ep_reward:200.0
#
# Episode#:278 ep_reward:199.0
#
# Episode#:279 ep_reward:176.0
#
# Episode#:280 ep_reward:137.0
#
# Episode#:281 ep_reward:200.0
#
# Episode#:282 ep_reward:200.0
#
# Episode#:283 ep_reward:200.0
#
# Episode#:284 ep_reward:189.0
#
# Episode#:285 ep_reward:200.0
#
# Episode#:286 ep_reward:200.0
#
# Episode#:287 ep_reward:200.0
#
# Episode#:288 ep_reward:200.0
#
# Episode#:289 ep_reward:200.0
#
# Episode#:290 ep_reward:200.0
#
# Episode#:291 ep_reward:200.0
#
# Episode#:292 ep_reward:198.0
#
# Episode#:293 ep_reward:200.0
#
# Episode#:294 ep_reward:200.0
#
# Episode#:295 ep_reward:183.0
#
# Episode#:296 ep_reward:200.0
#
# Episode#:297 ep_reward:200.0
#
# Episode#:298 ep_reward:200.0
#
# Episode#:299 ep_reward:187.0
#
# Episode#:300 ep_reward:200.0
#
# Episode#:301 ep_reward:181.0
#
# Episode#:302 ep_reward:119.0
#
# Episode#:303 ep_reward:149.0
#
# Episode#:304 ep_reward:126.0
#
# Episode#:305 ep_reward:119.0
#
# Episode#:306 ep_reward:111.0
#
# Episode#:307 ep_reward:140.0
#
# Episode#:308 ep_reward:200.0
#
# Episode#:309 ep_reward:200.0
#
# Episode#:310 ep_reward:165.0
#
# Episode#:311 ep_reward:200.0
#
# Episode#:312 ep_reward:197.0
#
# Episode#:313 ep_reward:175.0
#
# Episode#:314 ep_reward:146.0
#
# Episode#:315 ep_reward:200.0
#
# Episode#:316 ep_reward:197.0
#
# Episode#:317 ep_reward:88.0
#
# Episode#:318 ep_reward:139.0
#
# Episode#:319 ep_reward:97.0
#
# Episode#:320 ep_reward:100.0
#
# Episode#:321 ep_reward:148.0
#
# Episode#:322 ep_reward:110.0
#
# Episode#:323 ep_reward:106.0
#
# Episode#:324 ep_reward:84.0
#
# Episode#:325 ep_reward:83.0
#
# Episode#:326 ep_reward:152.0
#
# Episode#:327 ep_reward:59.0
#
# Episode#:328 ep_reward:118.0
#
# Episode#:329 ep_reward:103.0
#
# Episode#:330 ep_reward:101.0
#
# Episode#:331 ep_reward:80.0
#
# Episode#:332 ep_reward:74.0
#
# Episode#:333 ep_reward:98.0
#
# Episode#:334 ep_reward:197.0
#
# Episode#:335 ep_reward:124.0
#
# Episode#:336 ep_reward:200.0
#
# Episode#:337 ep_reward:180.0
#
# Episode#:338 ep_reward:200.0
#
# Episode#:339 ep_reward:133.0
#
# Episode#:340 ep_reward:144.0
#
# Episode#:341 ep_reward:124.0
#
# Episode#:342 ep_reward:141.0
#
# Episode#:343 ep_reward:161.0
#
# Episode#:344 ep_reward:134.0
#
# Episode#:345 ep_reward:149.0
#
# Episode#:346 ep_reward:200.0
#
# Episode#:347 ep_reward:200.0
#
# Episode#:348 ep_reward:200.0
#
# Episode#:349 ep_reward:100.0
#
# Episode#:350 ep_reward:129.0
#
# Episode#:351 ep_reward:188.0
#
# Episode#:352 ep_reward:120.0
#
# Episode#:353 ep_reward:176.0
#
# Episode#:354 ep_reward:200.0
#
# Episode#:355 ep_reward:136.0
#
# Episode#:356 ep_reward:127.0
#
# Episode#:357 ep_reward:200.0
#
# Episode#:358 ep_reward:180.0
#
# Episode#:359 ep_reward:184.0
#
# Episode#:360 ep_reward:156.0
#
# Episode#:361 ep_reward:140.0
#
# Episode#:362 ep_reward:144.0
#
# Episode#:363 ep_reward:200.0
#
# Episode#:364 ep_reward:200.0
#
# Episode#:365 ep_reward:172.0
#
# Episode#:366 ep_reward:131.0
#
# Episode#:367 ep_reward:121.0
#
# Episode#:368 ep_reward:123.0
#
# Episode#:369 ep_reward:137.0
#
# Episode#:370 ep_reward:150.0
#
# Episode#:371 ep_reward:111.0
#
# Episode#:372 ep_reward:188.0
#
# Episode#:373 ep_reward:89.0
#
# Episode#:374 ep_reward:90.0
#
# Episode#:375 ep_reward:108.0
#
# Episode#:376 ep_reward:109.0
#
# Episode#:377 ep_reward:158.0
#
# Episode#:378 ep_reward:88.0
#
# Episode#:379 ep_reward:107.0
#
# Episode#:380 ep_reward:95.0
#
# Episode#:381 ep_reward:99.0
#
# Episode#:382 ep_reward:124.0
#
# Episode#:383 ep_reward:94.0
#
# Episode#:384 ep_reward:83.0
#
# Episode#:385 ep_reward:113.0
#
# Episode#:386 ep_reward:139.0
#
# Episode#:387 ep_reward:97.0
#
# Episode#:388 ep_reward:116.0
#
# Episode#:389 ep_reward:92.0
#
# Episode#:390 ep_reward:113.0
#
# Episode#:391 ep_reward:114.0
#
# Episode#:392 ep_reward:130.0
#
# Episode#:393 ep_reward:118.0
#
# Episode#:394 ep_reward:175.0
#
# Episode#:395 ep_reward:141.0
#
# Episode#:396 ep_reward:140.0
#
# Episode#:397 ep_reward:171.0
#
# Episode#:398 ep_reward:200.0
#
# Episode#:399 ep_reward:121.0
#
# Episode#:400 ep_reward:102.0
#
# Episode#:401 ep_reward:120.0
#
# Episode#:402 ep_reward:137.0
#
# Episode#:403 ep_reward:153.0
#
# Episode#:404 ep_reward:150.0
#
# Episode#:405 ep_reward:184.0
#
# Episode#:406 ep_reward:172.0
#
# Episode#:407 ep_reward:108.0
#
# Episode#:408 ep_reward:168.0
#
# Episode#:409 ep_reward:144.0
#
# Episode#:410 ep_reward:123.0
#
# Episode#:411 ep_reward:125.0
#
# Episode#:412 ep_reward:128.0
#
# Episode#:413 ep_reward:123.0
#
# Episode#:414 ep_reward:111.0
#
# Episode#:415 ep_reward:125.0
#
# Episode#:416 ep_reward:125.0
#
# Episode#:417 ep_reward:102.0
#
# Episode#:418 ep_reward:118.0
#
# Episode#:419 ep_reward:113.0
#
# Episode#:420 ep_reward:111.0
#
# Episode#:421 ep_reward:121.0
#
# Episode#:422 ep_reward:129.0
#
# Episode#:423 ep_reward:105.0
#
# Episode#:424 ep_reward:123.0
#
# Episode#:425 ep_reward:133.0
#
# Episode#:426 ep_reward:144.0
#
# Episode#:427 ep_reward:123.0
#
# Episode#:428 ep_reward:123.0
#
# Episode#:429 ep_reward:124.0
#
# Episode#:430 ep_reward:120.0
#
# Episode#:431 ep_reward:197.0
#
# Episode#:432 ep_reward:156.0
#
# Episode#:433 ep_reward:159.0
#
# Episode#:434 ep_reward:121.0
#
# Episode#:435 ep_reward:119.0
#
# Episode#:436 ep_reward:131.0
#
# Episode#:437 ep_reward:115.0
#
# Episode#:438 ep_reward:115.0
#
# Episode#:439 ep_reward:122.0
#
# Episode#:440 ep_reward:137.0
#
# Episode#:441 ep_reward:120.0
#
# Episode#:442 ep_reward:113.0
#
# Episode#:443 ep_reward:97.0
#
# Episode#:444 ep_reward:102.0
#
# Episode#:445 ep_reward:111.0
#
# Episode#:446 ep_reward:102.0
#
# Episode#:447 ep_reward:113.0
#
# Episode#:448 ep_reward:157.0
#
# Episode#:449 ep_reward:139.0
#
# Episode#:450 ep_reward:146.0
#
# Episode#:451 ep_reward:151.0
#
# Episode#:452 ep_reward:143.0
#
# Episode#:453 ep_reward:183.0
#
# Episode#:454 ep_reward:136.0
#
# Episode#:455 ep_reward:138.0
#
# Episode#:456 ep_reward:119.0
#
# Episode#:457 ep_reward:119.0
#
# Episode#:458 ep_reward:200.0
#
# Episode#:459 ep_reward:120.0
#
# Episode#:460 ep_reward:140.0
#
# Episode#:461 ep_reward:127.0
#
# Episode#:462 ep_reward:166.0
#
# Episode#:463 ep_reward:129.0
#
# Episode#:464 ep_reward:117.0
#
# Episode#:465 ep_reward:128.0
#
# Episode#:466 ep_reward:156.0
#
# Episode#:467 ep_reward:108.0
#
# Episode#:468 ep_reward:165.0
#
# Episode#:469 ep_reward:112.0
#
# Episode#:470 ep_reward:121.0
#
# Episode#:471 ep_reward:142.0
#
# Episode#:472 ep_reward:131.0
#
# Episode#:473 ep_reward:118.0
#
# Episode#:474 ep_reward:71.0
#
# Episode#:475 ep_reward:104.0
#
# Episode#:476 ep_reward:114.0
#
# Episode#:477 ep_reward:115.0
#
# Episode#:478 ep_reward:132.0
#
# Episode#:479 ep_reward:126.0
#
# Episode#:480 ep_reward:131.0
#
# Episode#:481 ep_reward:119.0
#
# Episode#:482 ep_reward:122.0
#
# Episode#:483 ep_reward:124.0
#
# Episode#:484 ep_reward:150.0
#
# Episode#:485 ep_reward:115.0
#
# Episode#:486 ep_reward:102.0
#
# Episode#:487 ep_reward:107.0
#
# Episode#:488 ep_reward:91.0
#
# Episode#:489 ep_reward:108.0
#
# Episode#:490 ep_reward:142.0
#
# Episode#:491 ep_reward:115.0
#
# Episode#:492 ep_reward:151.0
#
# Episode#:493 ep_reward:116.0
#
# Episode#:494 ep_reward:173.0
#
# Episode#:495 ep_reward:134.0
#
# Episode#:496 ep_reward:138.0
#
# Episode#:497 ep_reward:143.0
#
# Episode#:498 ep_reward:115.0
#
# Episode#:499 ep_reward:114.0
#
# Episode#:500 ep_reward:123.0
#
# Episode#:501 ep_reward:172.0
#
# Episode#:502 ep_reward:156.0
#
# Episode#:503 ep_reward:115.0
#
# Episode#:504 ep_reward:120.0
#
# Episode#:505 ep_reward:148.0
#
# Episode#:506 ep_reward:200.0
#
# Episode#:507 ep_reward:179.0
#
# Episode#:508 ep_reward:151.0
#
# Episode#:509 ep_reward:200.0
#
# Episode#:510 ep_reward:200.0
#
# Episode#:511 ep_reward:122.0
#
# Episode#:512 ep_reward:146.0
#
# Episode#:513 ep_reward:200.0
#
# Episode#:514 ep_reward:200.0
#
# Episode#:515 ep_reward:200.0
#
# Episode#:516 ep_reward:200.0
#
# Episode#:517 ep_reward:145.0
#
# Episode#:518 ep_reward:200.0
#
# Episode#:519 ep_reward:183.0
#
# Episode#:520 ep_reward:150.0
#
# Episode#:521 ep_reward:200.0
#
# Episode#:522 ep_reward:156.0
#
# Episode#:523 ep_reward:200.0
#
# Episode#:524 ep_reward:165.0
#
# Episode#:525 ep_reward:200.0
#
# Episode#:526 ep_reward:158.0
#
# Episode#:527 ep_reward:137.0
#
# Episode#:528 ep_reward:200.0
#
# Episode#:529 ep_reward:135.0
#
# Episode#:530 ep_reward:149.0
#
# Episode#:531 ep_reward:158.0
#
# Episode#:532 ep_reward:161.0
#
# Episode#:533 ep_reward:148.0
#
# Episode#:534 ep_reward:124.0
#
# Episode#:535 ep_reward:167.0
#
# Episode#:536 ep_reward:146.0
#
# Episode#:537 ep_reward:136.0
#
# Episode#:538 ep_reward:167.0
#
# Episode#:539 ep_reward:134.0
#
# Episode#:540 ep_reward:199.0
#
# Episode#:541 ep_reward:173.0
#
# Episode#:542 ep_reward:172.0
#
# Episode#:543 ep_reward:200.0
#
# Episode#:544 ep_reward:173.0
#
# Episode#:545 ep_reward:146.0
#
# Episode#:546 ep_reward:193.0
#
# Episode#:547 ep_reward:183.0
#
# Episode#:548 ep_reward:131.0
#
# Episode#:549 ep_reward:200.0
#
# Episode#:550 ep_reward:152.0
#
# Episode#:551 ep_reward:161.0
#
# Episode#:552 ep_reward:155.0
#
# Episode#:553 ep_reward:200.0
#
# Episode#:554 ep_reward:154.0
#
# Episode#:555 ep_reward:185.0
#
# Episode#:556 ep_reward:200.0
# Episode#:557 ep_reward:127.0
#
# Episode#:558 ep_reward:132.0
#
# Episode#:559 ep_reward:128.0
#
# Episode#:560 ep_reward:147.0
#
# Episode#:561 ep_reward:144.0
#
# Episode#:562 ep_reward:142.0
#
# Episode#:563 ep_reward:121.0
#
# Episode#:564 ep_reward:155.0
#
# Episode#:565 ep_reward:126.0
#
# Episode#:566 ep_reward:125.0
#
# Episode#:567 ep_reward:117.0
#
# Episode#:568 ep_reward:129.0
#
# Episode#:569 ep_reward:158.0
#
# Episode#:570 ep_reward:200.0
#
# Episode#:571 ep_reward:200.0
#
# Episode#:572 ep_reward:200.0
#
# Episode#:573 ep_reward:186.0
#
# Episode#:574 ep_reward:200.0
#
# Episode#:575 ep_reward:155.0
#
# Episode#:576 ep_reward:196.0
#
# Episode#:577 ep_reward:182.0
#
# Episode#:578 ep_reward:169.0
#
# Episode#:579 ep_reward:126.0
#
# Episode#:580 ep_reward:163.0
#
# Episode#:581 ep_reward:200.0
#
# Episode#:582 ep_reward:145.0
#
# Episode#:583 ep_reward:200.0
#
# Episode#:584 ep_reward:138.0
#
# Episode#:585 ep_reward:194.0
#
# Episode#:586 ep_reward:175.0
#
# Episode#:587 ep_reward:127.0
#
# Episode#:588 ep_reward:134.0
#
# Episode#:589 ep_reward:133.0
#
# Episode#:590 ep_reward:131.0
#
# Episode#:591 ep_reward:136.0
#
# Episode#:592 ep_reward:121.0
#
# Episode#:593 ep_reward:141.0
#
# Episode#:594 ep_reward:115.0
#
# Episode#:595 ep_reward:133.0
#
# Episode#:596 ep_reward:168.0
#
# Episode#:597 ep_reward:117.0
#
# Episode#:598 ep_reward:123.0
#
# Episode#:599 ep_reward:127.0
#
# Episode#:600 ep_reward:151.0
#
# Episode#:601 ep_reward:137.0
#
# Episode#:602 ep_reward:173.0
#
# Episode#:603 ep_reward:106.0
#
# Episode#:604 ep_reward:163.0
#
# Episode#:605 ep_reward:119.0
#
# Episode#:606 ep_reward:117.0
#
# Episode#:607 ep_reward:128.0
#
# Episode#:608 ep_reward:132.0
#
# Episode#:609 ep_reward:186.0
#
# Episode#:610 ep_reward:140.0
#
# Episode#:611 ep_reward:138.0
#
# Episode#:612 ep_reward:128.0
#
# Episode#:613 ep_reward:110.0
#
# Episode#:614 ep_reward:163.0
#
# Episode#:615 ep_reward:143.0
#
# Episode#:616 ep_reward:144.0
#
# Episode#:617 ep_reward:126.0
#
# Episode#:618 ep_reward:147.0
#
# Episode#:619 ep_reward:131.0
#
# Episode#:620 ep_reward:163.0
#
# Episode#:621 ep_reward:200.0
#
# Episode#:622 ep_reward:107.0
#
# Episode#:623 ep_reward:118.0
#
# Episode#:624 ep_reward:113.0
#
# Episode#:625 ep_reward:113.0
#
# Episode#:626 ep_reward:110.0
#
# Episode#:627 ep_reward:173.0
#
# Episode#:628 ep_reward:71.0
#
# Episode#:629 ep_reward:114.0
#
# Episode#:630 ep_reward:140.0
#
# Episode#:631 ep_reward:173.0
#
# Episode#:632 ep_reward:128.0
#
# Episode#:633 ep_reward:129.0
#
# Episode#:634 ep_reward:144.0
#
# Episode#:635 ep_reward:122.0
#
# Episode#:636 ep_reward:121.0
#
# Episode#:637 ep_reward:172.0
#
# Episode#:638 ep_reward:141.0
#
# Episode#:639 ep_reward:200.0
#
# Episode#:640 ep_reward:168.0
#
# Episode#:641 ep_reward:136.0
#
# Episode#:642 ep_reward:145.0
#
# Episode#:643 ep_reward:132.0
#
# Episode#:644 ep_reward:142.0
#
# Episode#:645 ep_reward:166.0
#
# Episode#:646 ep_reward:115.0
#
# Episode#:647 ep_reward:139.0
#
# Episode#:648 ep_reward:131.0
#
# Episode#:649 ep_reward:172.0
#
# Episode#:650 ep_reward:126.0
#
# Episode#:651 ep_reward:125.0
#
# Episode#:652 ep_reward:140.0
#
# Episode#:653 ep_reward:117.0
#
# Episode#:654 ep_reward:109.0
#
# Episode#:655 ep_reward:115.0
#
# Episode#:656 ep_reward:148.0
#
# Episode#:657 ep_reward:117.0
#
# Episode#:658 ep_reward:198.0
#
# Episode#:659 ep_reward:130.0
#
# Episode#:660 ep_reward:141.0
#
# Episode#:661 ep_reward:142.0
#
# Episode#:662 ep_reward:113.0
#
# Episode#:663 ep_reward:114.0
#
# Episode#:664 ep_reward:107.0
#
# Episode#:665 ep_reward:107.0
#
# Episode#:666 ep_reward:174.0
#
# Episode#:667 ep_reward:133.0
#
# Episode#:668 ep_reward:194.0
#
# Episode#:669 ep_reward:158.0
#
# Episode#:670 ep_reward:179.0
#
# Episode#:671 ep_reward:119.0
#
# Episode#:672 ep_reward:200.0
#
# Episode#:673 ep_reward:200.0
#
# Episode#:674 ep_reward:173.0
#
# Episode#:675 ep_reward:162.0
#
# Episode#:676 ep_reward:181.0
#
# Episode#:677 ep_reward:141.0
#
# Episode#:678 ep_reward:134.0
#
# Episode#:679 ep_reward:122.0
#
# Episode#:680 ep_reward:161.0
#
# Episode#:681 ep_reward:179.0
#
# Episode#:682 ep_reward:129.0
#
# Episode#:683 ep_reward:148.0
#
# Episode#:684 ep_reward:144.0
#
# Episode#:685 ep_reward:119.0
#
# Episode#:686 ep_reward:145.0
#
# Episode#:687 ep_reward:200.0
#
# Episode#:688 ep_reward:191.0
#
# Episode#:689 ep_reward:180.0
#
# Episode#:690 ep_reward:130.0
#
# Episode#:691 ep_reward:153.0
#
# Episode#:692 ep_reward:127.0
#
# Episode#:693 ep_reward:124.0
#
# Episode#:694 ep_reward:121.0
#
# Episode#:695 ep_reward:138.0
#
# Episode#:696 ep_reward:121.0
#
# Episode#:697 ep_reward:124.0
#
# Episode#:698 ep_reward:200.0
#
# Episode#:699 ep_reward:184.0
#
# Episode#:700 ep_reward:200.0
#
# Episode#:701 ep_reward:145.0
#
# Episode#:702 ep_reward:200.0
#
# Episode#:703 ep_reward:142.0
#
# Episode#:704 ep_reward:200.0
#
# Episode#:705 ep_reward:141.0
#
# Episode#:706 ep_reward:138.0
#
# Episode#:707 ep_reward:157.0
#
# Episode#:708 ep_reward:158.0
#
# Episode#:709 ep_reward:161.0
#
# Episode#:710 ep_reward:139.0
#
# Episode#:711 ep_reward:172.0
#
# Episode#:712 ep_reward:145.0
#
# Episode#:713 ep_reward:127.0
#
# Episode#:714 ep_reward:172.0
#
# Episode#:715 ep_reward:175.0
#
# Episode#:716 ep_reward:127.0
#
# Episode#:717 ep_reward:166.0
#
# Episode#:718 ep_reward:147.0
#
# Episode#:719 ep_reward:168.0
#
# Episode#:720 ep_reward:154.0
#
# Episode#:721 ep_reward:137.0
#
# Episode#:722 ep_reward:130.0
#
# Episode#:723 ep_reward:125.0
#
# Episode#:724 ep_reward:121.0
#
# Episode#:725 ep_reward:127.0
#
# Episode#:726 ep_reward:200.0
#
# Episode#:727 ep_reward:188.0
#
# Episode#:728 ep_reward:144.0
#
# Episode#:729 ep_reward:148.0
#
# Episode#:730 ep_reward:169.0
#
# Episode#:731 ep_reward:127.0
#
# Episode#:732 ep_reward:133.0
#
# Episode#:733 ep_reward:136.0
#
# Episode#:734 ep_reward:137.0
#
# Episode#:735 ep_reward:128.0
#
# Episode#:736 ep_reward:125.0
#
# Episode#:737 ep_reward:146.0
#
# Episode#:738 ep_reward:138.0
#
# Episode#:739 ep_reward:123.0
#
# Episode#:740 ep_reward:162.0
#
# Episode#:741 ep_reward:140.0
#
# Episode#:742 ep_reward:200.0
#
# Episode#:743 ep_reward:184.0
#
# Episode#:744 ep_reward:200.0
#
# Episode#:745 ep_reward:125.0
#
# Episode#:746 ep_reward:164.0
#
# Episode#:747 ep_reward:124.0
#
# Episode#:748 ep_reward:142.0
#
# Episode#:749 ep_reward:145.0
#
# Episode#:750 ep_reward:151.0
#
# Episode#:751 ep_reward:159.0
#
# Episode#:752 ep_reward:143.0
#
# Episode#:753 ep_reward:129.0
#
# Episode#:754 ep_reward:157.0
#
# Episode#:755 ep_reward:129.0
#
# Episode#:756 ep_reward:169.0
#
# Episode#:757 ep_reward:119.0
#
# Episode#:758 ep_reward:139.0
#
# Episode#:759 ep_reward:135.0
#
# Episode#:760 ep_reward:165.0
#
# Episode#:761 ep_reward:169.0
#
# Episode#:762 ep_reward:116.0
#
# Episode#:763 ep_reward:158.0
#
# Episode#:764 ep_reward:134.0
#
# Episode#:765 ep_reward:200.0
#
# Episode#:766 ep_reward:143.0
#
# Episode#:767 ep_reward:123.0
#
# Episode#:768 ep_reward:124.0
#
# Episode#:769 ep_reward:135.0
#
# Episode#:770 ep_reward:143.0
#
# Episode#:771 ep_reward:145.0
#
# Episode#:772 ep_reward:148.0
#
# Episode#:773 ep_reward:117.0
#
# Episode#:774 ep_reward:144.0
#
# Episode#:775 ep_reward:200.0
#
# Episode#:776 ep_reward:130.0
#
# Episode#:777 ep_reward:133.0
#
# Episode#:778 ep_reward:117.0
#
# Episode#:779 ep_reward:145.0
#
# Episode#:780 ep_reward:122.0
#
# Episode#:781 ep_reward:136.0
#
# Episode#:782 ep_reward:122.0
#
# Episode#:783 ep_reward:114.0
#
# Episode#:784 ep_reward:145.0
#
# Episode#:785 ep_reward:134.0
#
# Episode#:786 ep_reward:125.0
#
# Episode#:787 ep_reward:200.0
#
# Episode#:788 ep_reward:200.0
#
# Episode#:789 ep_reward:152.0
#
# Episode#:790 ep_reward:139.0
#
# Episode#:791 ep_reward:146.0
#
# Episode#:792 ep_reward:200.0
#
# Episode#:793 ep_reward:200.0
#
# Episode#:794 ep_reward:200.0
#
# Episode#:795 ep_reward:129.0
#
# Episode#:796 ep_reward:200.0
#
# Episode#:797 ep_reward:189.0
#
# Episode#:798 ep_reward:192.0
#
# Episode#:799 ep_reward:150.0
#
# Episode#:800 ep_reward:200.0
#
# Episode#:801 ep_reward:200.0
#
# Episode#:802 ep_reward:157.0
#
# Episode#:803 ep_reward:177.0
#
# Episode#:804 ep_reward:155.0
#
# Episode#:805 ep_reward:186.0
#
# Episode#:806 ep_reward:200.0
#
# Episode#:807 ep_reward:200.0
#
# Episode#:808 ep_reward:153.0
#
# Episode#:809 ep_reward:200.0
#
# Episode#:810 ep_reward:200.0
#
# Episode#:811 ep_reward:172.0
#
# Episode#:812 ep_reward:200.0
#
# Episode#:813 ep_reward:131.0
#
# Episode#:814 ep_reward:172.0
#
# Episode#:815 ep_reward:151.0
#
# Episode#:816 ep_reward:155.0
#
# Episode#:817 ep_reward:154.0
#
# Episode#:818 ep_reward:139.0
#
# Episode#:819 ep_reward:200.0
#
# Episode#:820 ep_reward:181.0
#
# Episode#:821 ep_reward:185.0
#
# Episode#:822 ep_reward:200.0
#
# Episode#:823 ep_reward:145.0
#
# Episode#:824 ep_reward:122.0
#
# Episode#:825 ep_reward:142.0
#
# Episode#:826 ep_reward:156.0
#
# Episode#:827 ep_reward:129.0
#
# Episode#:828 ep_reward:200.0
#
# Episode#:829 ep_reward:141.0
#
# Episode#:830 ep_reward:156.0
#
# Episode#:831 ep_reward:105.0
#
# Episode#:832 ep_reward:142.0
#
# Episode#:833 ep_reward:114.0
#
# Episode#:834 ep_reward:142.0
#
# Episode#:835 ep_reward:147.0
#
# Episode#:836 ep_reward:178.0
#
# Episode#:837 ep_reward:156.0
#
# Episode#:838 ep_reward:153.0
#
# Episode#:839 ep_reward:200.0
#
# Episode#:840 ep_reward:200.0
#
# Episode#:841 ep_reward:159.0
#
# Episode#:842 ep_reward:182.0
#
# Episode#:843 ep_reward:200.0
#
# Episode#:844 ep_reward:125.0
#
# Episode#:845 ep_reward:184.0
#
# Episode#:846 ep_reward:200.0
#
# Episode#:847 ep_reward:150.0
#
# Episode#:848 ep_reward:200.0
#
# Episode#:849 ep_reward:145.0
#
# Episode#:850 ep_reward:200.0
#
# Episode#:851 ep_reward:162.0
#
# Episode#:852 ep_reward:200.0
#
# Episode#:853 ep_reward:162.0
#
# Episode#:854 ep_reward:157.0
#
# Episode#:855 ep_reward:169.0
#
# Episode#:856 ep_reward:200.0
#
# Episode#:857 ep_reward:200.0
#
# Episode#:858 ep_reward:138.0
#
# Episode#:859 ep_reward:128.0
#
# Episode#:860 ep_reward:131.0
#
# Episode#:861 ep_reward:200.0
#
# Episode#:862 ep_reward:199.0
#
# Episode#:863 ep_reward:200.0
#
# Episode#:864 ep_reward:146.0
#
# Episode#:865 ep_reward:153.0
#
# Episode#:866 ep_reward:151.0
#
# Episode#:867 ep_reward:200.0
#
# Episode#:868 ep_reward:200.0
#
# Episode#:869 ep_reward:200.0
#
# Episode#:870 ep_reward:121.0
#
# Episode#:871 ep_reward:171.0
#
# Episode#:872 ep_reward:94.0
#
# Episode#:873 ep_reward:134.0
#
# Episode#:874 ep_reward:200.0
#
# Episode#:875 ep_reward:141.0
#
# Episode#:876 ep_reward:147.0
#
# Episode#:877 ep_reward:200.0
#
# Episode#:878 ep_reward:139.0
#
# Episode#:879 ep_reward:200.0
#
# Episode#:880 ep_reward:184.0
#
# Episode#:881 ep_reward:163.0
#
# Episode#:882 ep_reward:133.0
#
# Episode#:883 ep_reward:193.0
#
# Episode#:884 ep_reward:174.0
#
# Episode#:885 ep_reward:174.0
#
# Episode#:886 ep_reward:200.0
#
# Episode#:887 ep_reward:133.0
#
# Episode#:888 ep_reward:156.0
#
# Episode#:889 ep_reward:200.0
#
# Episode#:890 ep_reward:160.0
#
# Episode#:891 ep_reward:137.0
#
# Episode#:892 ep_reward:200.0
#
# Episode#:893 ep_reward:133.0
#
# Episode#:894 ep_reward:145.0
#
# Episode#:895 ep_reward:162.0
#
# Episode#:896 ep_reward:132.0
#
# Episode#:897 ep_reward:166.0
#
# Episode#:898 ep_reward:146.0
#
# Episode#:899 ep_reward:141.0
#
# Episode#:900 ep_reward:120.0
#
# Episode#:901 ep_reward:129.0
#
# Episode#:902 ep_reward:133.0
#
# Episode#:903 ep_reward:142.0
#
# Episode#:904 ep_reward:170.0
#
# Episode#:905 ep_reward:145.0
#
# Episode#:906 ep_reward:154.0
#
# Episode#:907 ep_reward:121.0
#
# Episode#:908 ep_reward:120.0
#
# Episode#:909 ep_reward:171.0
#
# Episode#:910 ep_reward:135.0
#
# Episode#:911 ep_reward:150.0
#
# Episode#:912 ep_reward:188.0
#
# Episode#:913 ep_reward:126.0
#
# Episode#:914 ep_reward:155.0
#
# Episode#:915 ep_reward:170.0
#
# Episode#:916 ep_reward:143.0
#
# Episode#:917 ep_reward:200.0
#
# Episode#:918 ep_reward:127.0
#
# Episode#:919 ep_reward:200.0
#
# Episode#:920 ep_reward:200.0
#
# Episode#:921 ep_reward:200.0
#
# Episode#:922 ep_reward:200.0
#
# Episode#:923 ep_reward:200.0
#
# Episode#:924 ep_reward:200.0
#
# Episode#:925 ep_reward:175.0
#
# Episode#:926 ep_reward:200.0
#
# Episode#:927 ep_reward:200.0
#
# Episode#:928 ep_reward:200.0
#
# Episode#:929 ep_reward:200.0
#
# Episode#:930 ep_reward:147.0
#
# Episode#:931 ep_reward:159.0
#
# Episode#:932 ep_reward:192.0
#
# Episode#:933 ep_reward:200.0
#
# Episode#:934 ep_reward:200.0
#
# Episode#:935 ep_reward:200.0
#
# Episode#:936 ep_reward:200.0
#
# Episode#:937 ep_reward:200.0
#
# Episode#:938 ep_reward:200.0
#
# Episode#:939 ep_reward:182.0
#
# Episode#:940 ep_reward:152.0
#
# Episode#:941 ep_reward:200.0
#
# Episode#:942 ep_reward:200.0
#
# Episode#:943 ep_reward:150.0
#
# Episode#:944 ep_reward:200.0
#
# Episode#:945 ep_reward:200.0
#
# Episode#:946 ep_reward:200.0
#
# Episode#:947 ep_reward:200.0
#
# Episode#:948 ep_reward:179.0
#
# Episode#:949 ep_reward:200.0
#
# Episode#:950 ep_reward:200.0
#
# Episode#:951 ep_reward:191.0
#
# Episode#:952 ep_reward:200.0
#
# Episode#:953 ep_reward:200.0
#
# Episode#:954 ep_reward:137.0
#
# Episode#:955 ep_reward:200.0
#
# Episode#:956 ep_reward:193.0
#
# Episode#:957 ep_reward:162.0
#
# Episode#:958 ep_reward:200.0
#
# Episode#:959 ep_reward:200.0
#
# Episode#:960 ep_reward:167.0
#
# Episode#:961 ep_reward:162.0
#
# Episode#:962 ep_reward:200.0
#
# Episode#:963 ep_reward:200.0
#
# Episode#:964 ep_reward:200.0
#
# Episode#:965 ep_reward:200.0
#
# Episode#:966 ep_reward:200.0
#
# Episode#:967 ep_reward:200.0
#
# Episode#:968 ep_reward:200.0
#
# Episode#:969 ep_reward:200.0
#
# Episode#:970 ep_reward:200.0
#
# Episode#:971 ep_reward:200.0
#
# Episode#:972 ep_reward:200.0
#
# Episode#:973 ep_reward:193.0
#
# Episode#:974 ep_reward:200.0
#
# Episode#:975 ep_reward:161.0
#
# Episode#:976 ep_reward:200.0
#
# Episode#:977 ep_reward:164.0
#
# Episode#:978 ep_reward:177.0
#
# Episode#:979 ep_reward:200.0
#
# Episode#:980 ep_reward:200.0
#
# Episode#:981 ep_reward:200.0
#
# Episode#:982 ep_reward:200.0
#
# Episode#:983 ep_reward:200.0
#
# Episode#:984 ep_reward:200.0
#
# Episode#:985 ep_reward:200.0
#
# Episode#:986 ep_reward:200.0
#
# Episode#:987 ep_reward:200.0
#
# Episode#:988 ep_reward:200.0
#
# Episode#:989 ep_reward:200.0
#
# Episode#:990 ep_reward:200.0
#
# Episode#:991 ep_reward:156.0
#
# Episode#:992 ep_reward:200.0
#
# Episode#:993 ep_reward:175.0
#
# Episode#:994 ep_reward:165.0
#
# Episode#:995 ep_reward:181.0
#
# Episode#:996 ep_reward:200.0
#
# Episode#:997 ep_reward:162.0
#
# Episode#:998 ep_reward:190.0
#
# Episode#:999 ep_reward:200.0

# %%
if __name__ == "__main__":
    env = gym.make("CartPole-v0")
    agent = Agent(env.action_space.n)
    num_episodes = 1000
    rewards = train(agent, env, num_episodes)
    createGraph(rewards)
